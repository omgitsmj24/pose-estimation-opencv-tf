# %%
import cv2
import time
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# !nvidia-smi
# Out:
# Mon Nov 15 13:40:07 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 472.12       Driver Version: 472.12       CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name            TCC/WDDM | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ... WDDM  | 00000000:01:00.0  On |                  N/A |
# |  0%   42C    P8    17W / 160W |    973MiB /  6144MiB |      2%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A       268    C+G   ...icrosoft VS Code\Code.exe    N/A      |
# |    0   N/A  N/A      1392    C+G   Insufficient Permissions        N/A      |
# |    0   N/A  N/A      4000    C+G   ...wekyb3d8bbwe\Video.UI.exe    N/A      |
# |    0   N/A  N/A      4380    C+G   ...nputApp\TextInputHost.exe    N/A      |
# |    0   N/A  N/A      4728    C+G   ... WARP\Cloudflare WARP.exe    N/A      |
# |    0   N/A  N/A      4752    C+G   ...lPanel\SystemSettings.exe    N/A      |
# |    0   N/A  N/A      6804    C+G   ...Microsoft.Msn.Weather.exe    N/A      |
# |    0   N/A  N/A      9188    C+G   ...t\Teams\current\Teams.exe    N/A      |
# |    0   N/A  N/A      9248    C+G   C:\WINDOWS\explorer.exe         N/A      |
# |    0   N/A  N/A      9636    C+G   ...me\Application\chrome.exe    N/A      |
# |    0   N/A  N/A      9748    C+G   ...t\Teams\current\Teams.exe    N/A      |
# |    0   N/A  N/A     10420    C+G   ...5n1h2txyewy\SearchApp.exe    N/A      |
# |    0   N/A  N/A     10540    C+G   ...artMenuExperienceHost.exe    N/A      |
# |    0   N/A  N/A     10984    C+G   ...TeamViewer\TeamViewer.exe    N/A      |
# |    0   N/A  N/A     11768    C+G   ...ekyb3d8bbwe\YourPhone.exe    N/A      |
# |    0   N/A  N/A     12536    C+G   ...cw5n1h2txyewy\LockApp.exe    N/A      |
# |    0   N/A  N/A     15096    C+G   ...in7x64\steamwebhelper.exe    N/A      |
# |    0   N/A  N/A     15848    C+G   ...ram Files\LGHUB\lghub.exe    N/A      |
# |    0   N/A  N/A     18356    C+G   ...y\ShellExperienceHost.exe    N/A      |
# |    0   N/A  N/A     18900    C+G   ...\app-1.0.9003\Discord.exe    N/A      |
# |    0   N/A  N/A     20172    C+G   D:\Battle.net\Battle.net.exe    N/A      |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ## Specify the model to be used
# COCO and MPI are body pose estimation model. COCO has 18 points and MPI has 15 points as output.

# %%
MODE = "MPI"

if MODE is "COCO":
    protoFile = "openpose/models/pose/coco/pose_deploy_linevec.prototxt"
    weightsFile = "openpose/models/pose/coco/pose_iter_440000.caffemodel"
    nPoints = 18
    POSE_PAIRS = [ [1,0],[1,2],[1,5],[2,3],[3,4],[5,6],[6,7],[1,8],[8,9],[9,10],[1,11],[11,12],[12,13],[0,14],[0,15],[14,16],[15,17]]

elif MODE is "MPI" :
    protoFile = "openpose/models/pose/mpi/pose_deploy_linevec_faster_4_stages.prototxt"
    weightsFile = "openpose/models/pose/mpi/pose_iter_160000.caffemodel"
    nPoints = 15
    POSE_PAIRS = [[0,1], [1,2], [2,3], [3,4], [1,5], [5,6], [6,7], [1,14], [14,8], [8,9], [9,10], [14,11], [11,12], [12,13] ]

# %% [markdown]
# #### Loading an image with multiple people and checking what the model sees

# %%
image1 = cv2.imread("multiple.jpeg")
frameWidth = image1.shape[1]
frameHeight = image1.shape[0]
threshold = 0.1

# %% [markdown]
# #### Load the network and pass the image through the network

# %%
net = cv2.dnn.readNetFromCaffe(protoFile, weightsFile)

inWidth = 368
inHeight = 368
inpBlob = cv2.dnn.blobFromImage(image1, 1.0 / 255, (inWidth, inHeight),
                          (0, 0, 0), swapRB=False, crop=False)

net.setInput(inpBlob)
output = net.forward()
H = output.shape[2]
W = output.shape[3]
print(output.shape)
# Out:
# (1, 44, 46, 46)

# %% [markdown]
# #### Slice a probability map from the output for a specific keypoint and plot the heatmap ( after resizing ) on the image itself

# %%
i = 5
probMap = output[0, i, :, :]
probMap = cv2.resize(probMap, (image1.shape[1], image1.shape[0]))
plt.figure(figsize=[14,10])
plt.imshow(cv2.cvtColor(image1, cv2.COLOR_BGR2RGB))
plt.imshow(probMap, alpha=0.6)
plt.colorbar()
plt.axis("off")
# Out:
# (-0.5, 1279.5, 1071.5, -0.5)

# %% [markdown]
# #### plotting the affinity map on the image

# %%
i = 24
probMap = output[0, i, :, :]
probMap = cv2.resize(probMap, (image1.shape[1], image1.shape[0]))
plt.figure(figsize=[14,10])
plt.imshow(cv2.cvtColor(image1, cv2.COLOR_BGR2RGB))
plt.imshow(probMap, alpha=0.6)
plt.colorbar()
plt.axis("off")
# Out:
# (-0.5, 1279.5, 1071.5, -0.5)

# %% [markdown]
# #### finding the keypoints for a image with only single person

# %%
frame = cv2.imread("linh1.png")
frameCopy = np.copy(frame)
frameWidth = frame.shape[1]
frameHeight = frame.shape[0]
threshold = 0.1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-f89f70848984> in <module>
#       1 frame = cv2.imread("linh1.jpg")
#       2 frameCopy = np.copy(frame)
# ----> 3 frameWidth = frame.shape[1]
#       4 frameHeight = frame.shape[0]
#       5 threshold = 0.1
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %% [markdown]
# #### Pass it through the network

# %%
inpBlob = cv2.dnn.blobFromImage(frame, 1.0 / 255, (inWidth, inHeight),
                          (0, 0, 0), swapRB=False, crop=False)

net.setInput(inpBlob)

output = net.forward()
H = output.shape[2]
W = output.shape[3]

# %% [markdown]
# #### gather the points and plot the keypoints and the skeleton figure

# %%
# Empty list to store the detected keypoints
points = []

for i in range(nPoints):
    # confidence map of corresponding body's part.
    probMap = output[0, i, :, :]

    # Find global maxima of the probMap.
    minVal, prob, minLoc, point = cv2.minMaxLoc(probMap)
    
    # Scale the point to fit on the original image
    x = (frameWidth * point[0]) / W
    y = (frameHeight * point[1]) / H

    if prob > threshold : 
        cv2.circle(frameCopy, (int(x), int(y)), 8, (0, 255, 255), thickness=-1, lineType=cv2.FILLED)
        cv2.putText(frameCopy, "{}".format(i), (int(x), int(y)), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2, lineType=cv2.LINE_AA)
        cv2.circle(frame, (int(x), int(y)), 8, (0, 0, 255), thickness=-1, lineType=cv2.FILLED)

        # Add the point to the list if the probability is greater than the threshold
        points.append((int(x), int(y)))
    else :
        points.append(None)

# Draw Skeleton
for pair in POSE_PAIRS:
    partA = pair[0]
    partB = pair[1]

    if points[partA] and points[partB]:
        cv2.line(frame, points[partA], points[partB], (0, 255, 255), 3)

plt.figure(figsize=[10,10])
plt.imshow(cv2.cvtColor(frameCopy, cv2.COLOR_BGR2RGB))
plt.figure(figsize=[10,10])
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
